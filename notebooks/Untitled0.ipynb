# %%
# !pip install unidecode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.8 MB/s eta 0:00:00
# ...

# %%
from unidecode import unidecode

# %%
teste = "São José d'Rio Preto"
teste = unidecode(teste)
teste = teste.lower().split()
teste
# Out:
# ['sao', 'jose', "d'rio", 'preto']
